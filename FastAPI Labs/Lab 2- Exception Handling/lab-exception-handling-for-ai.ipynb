# %% [markdown]
# # Lab 2 — Exception Handling In FastAPI
#
# Difficulty: Beginner | ~35-40 min

# %% [markdown]
# ### Step 1: Install Dependencies
#
# We install the exact pinned versions of every library this lab needs. Run this cell first so everything is available for the rest of the notebook.

# %%
# !pip install fastapi==0.112.2 pydantic==2.8.2 httpx==0.28.1 openai==3.5.0 python-dotenv==1.2.3
# Out:
# Requirement already satisfied: fastapi==0.112.2 in d:\rohit\softwares\python\lib\site-packages (0.112.2)
# Requirement already satisfied: pydantic==2.8.2 in d:\rohit\softwares\python\lib\site-packages (2.8.2)
# Requirement already satisfied: httpx==0.28.1 in d:\rohit\softwares\python\lib\site-packages (0.28.1)
# Requirement already satisfied: openai==3.5.0 in d:\rohit\softwares\python\lib\site-packages (3.5.0)
# Requirement already satisfied: python-dotenv==1.2.3 in d:\rohit\softwares\python\lib\site-packages (1.2.3)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in d:\rohit\softwares\python\lib\site-packages (from fastapi==0.112.2) (0.38.6)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\rohit\softwares\python\lib\site-packages (from fastapi==0.112.2) (4.15.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\rohit\softwares\python\lib\site-packages (from pydantic==2.8.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\rohit\softwares\python\lib\site-packages (from pydantic==2.8.2) (2.20.1)
# Requirement already satisfied: anyio in d:\rohit\softwares\python\lib\site-packages (from httpx==0.28.1) (4.12.1)
# Requirement already satisfied: certifi in d:\rohit\softwares\python\lib\site-packages (from httpx==0.28.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\rohit\softwares\python\lib\site-packages (from httpx==0.28.1) (1.0.9)
# Requirement already satisfied: idna in d:\rohit\softwares\python\lib\site-packages (from httpx==0.28.1) (3.19)
# Requirement already satisfied: httpx2<3,>=2.7.0 in d:\rohit\softwares\python\lib\site-packages (from openai==3.5.0) (2.12.0)
# Requirement already satisfied: jiter<1,>=0.16.0 in d:\rohit\softwares\python\lib\site-packages (from openai==3.5.0) (0.16.0)
# Requirement already satisfied: sniffio in d:\rohit\softwares\python\lib\site-packages (from openai==3.5.0) (1.3.1)
# Requirement already satisfied: h11>=0.16 in d:\rohit\softwares\python\lib\site-packages (from httpcore==1.*->httpx==0.28.1) (0.16.0)
# Requirement already satisfied: httpcore2==2.12.0 in d:\rohit\softwares\python\lib\site-packages (from httpx2<3,>=2.7.0->openai==3.5.0) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in d:\rohit\softwares\python\lib\site-packages (from httpx2<3,>=2.7.0->openai==3.5.0) (0.10.4)
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Step 2: Imports and API key setup.
#
# We import the modules we need and load the OpenRouter API key from a `.env` file. The key is stored as a string — the actual `AsyncOpenAI` client instances are created inside the endpoint so each request gets a fresh client (this avoids event-loop binding issues with `TestClient`).

# %%
from fastapi import FastAPI, status
from fastapi.responses import JSONResponse
from fastapi.requests import Request
from fastapi.testclient import TestClient
from dotenv import load_dotenv
from openai import AsyncOpenAI
from openai import APIStatusError
import asyncio
import os

# Load OPEN_ROUTER_KEY from .env file in the current directory
load_dotenv()

api_key = os.getenv("OPEN_ROUTER_KEY")

if not api_key:
    api_key = input("Open Router API key: ")

app = FastAPI()

# %% [markdown]
# ### Step 3: Custom exception classes.
#
# Each class represents one distinct upstream failure that can happen when calling an LLM provider. We define them so that FastAPI can catch each one by type and return a structured error response with the right HTTP status code.

# %%
class LLMAuthError(Exception):
    """Raised when the OpenRouter API rejects the API key (invalid credentials)."""
    pass

class LLMSafetyError(Exception):
    """Raised when the response is technically successful but contains no usable content (safety block)."""
    pass

class LLMTimeoutError(Exception):
    """Raised when the OpenRouter API does not respond within the allowed time."""
    pass

class BadModelError(Exception):
    """Raised when the requested model name is invalid or has been deprecated."""
    pass

# %% [markdown]
# ### Step 4: Exception handlers registered on the app.
#
# `@app.exception_handler(ExceptionType)` tells FastAPI: "whenever this exception type is raised anywhere in the request lifecycle, call this function and return its response instead of crashing." Each handler below maps one custom exception to a specific HTTP status code and error message.

# %%
# 401 Unauthorized — the API key was rejected by OpenRouter
@app.exception_handler(LLMAuthError)
async def auth_error_handler(request: Request, exc: LLMAuthError):
    return JSONResponse(
        status_code = status.HTTP_401_UNAUTHORIZED,
        content = {
            "error": "authorization error",
            "message": "Unable to authenticate with OpenRouter API"
        }
    )

# %%
# 504 Gateway Timeout — the upstream LLM took too long to respond
@app.exception_handler(LLMTimeoutError)
async def timeout_handler(request: Request, exc: LLMTimeoutError):
    return JSONResponse(
        status_code = status.HTTP_504_GATEWAY_TIMEOUT,
        content = {
            "error": "Request Timed Out",
            "message": "OpenRouter API timed out"
        }
    )

# %%
# 502 Bad Gateway — the API call succeeded but the content is unusable (safety block)
@app.exception_handler(LLMSafetyError)
async def safety_error(request: Request, exc: LLMSafetyError):
    return JSONResponse(
        status_code= status.HTTP_502_BAD_GATEWAY,
        content = {
            "error": "unsafe content",
            "message": "unusable content returned"
        }
    )

# %%
# 404 Not Found — the model name is invalid or deprecated
@app.exception_handler(BadModelError)
async def bad_model(request: Request, exc: BadModelError):
    return JSONResponse(
        status_code = status.HTTP_404_NOT_FOUND,
        content = {
            "error": "Model Not found",
            "message": "Model name is not valid"
        }
    )

# %% [markdown]
# ### Step 5: The `/chat` endpoint — one try/except, four failure paths.
#
# This single endpoint handles everything: a normal call, plus four ways it can fail upstream. Each boolean query parameter simulates a different failure:
# - `deprecated_model=True` → invalid model name → `APIStatusError` status 400 → `BadModelError`
# - `timeout_error=True` → artificially short timeout → `asyncio.TimeoutError` → `LLMTimeoutError`
# - `bad_key=True` → invalid API key → `APIStatusError` status 401 → `LLMAuthError`
# - `unsafe_content=True` → directly raises `LLMSafetyError` (no SDK exception — simulates a safety block where the API succeeds but returns nothing usable)

# %%
@app.post("/chat")
async def chat(
    message: str, 
    deprecated_model: bool = False, 
    timeout_error: bool = False,
    bad_key: bool = False,
    unsafe_content: bool= False):
    try:

        # bad_key=True uses a deliberately invalid key to simulate an auth failure
        api = "Invalid_API_Key" if bad_key else api_key
        active_client = AsyncOpenAI(
            api_key=api,
            base_url="https://openrouter.ai/api/v1"
        )

        # Pick model name and timeout based on failure flags
        model_name = "invalid_model_name" if deprecated_model else "openrouter/free" 
        timeout = 0.1 if timeout_error else 20

        # Call OpenRouter with a hard timeout
        response = await asyncio.wait_for(
            active_client.chat.completions.create(
                model=model_name,
                messages=[{"role": "user", "content": message}],
            ),
            timeout=timeout
        )


    except APIStatusError as e:
        if e.status_code == 400:
            raise BadModelError()
        if e.status_code == 401:
            raise LLMAuthError()

        return JSONResponse(
            status_code=e.status_code,
            content={
                "details": e.message
            }
        ) #catches unhandled errors

    except asyncio.TimeoutError as e:
        raise LLMTimeoutError()

    # Simulate a safety block: raise directly (no SDK exception to catch)
    if unsafe_content:
        raise LLMSafetyError()

    return {"answer": response.choices[0].message.content}

# %% [markdown]
# ### Step 6: Demonstrations.
#
# We first confirm that a normal call works and returns a real answer. Then we trigger each of the four failure modes one by one, showing that each returns the expected status code and structured error message.
#
# Note: If 'Event Loop Closed' errors occurs, try rerunning the cell again. It will be fixed.

# %%
test_client = TestClient(app)

# %% [markdown]
# #### Case 1: Success case — no failure flags.
#
# A completely normal call. This confirms that the exception handlers do not interfere with the happy path — they only activate when something actually goes wrong upstream.

# %%
# Success case: normal call, no failure flags
question = "What is the capital of France?"
res = test_client.post(
    "/chat",
    params={"message": question}
)
print(res.status_code)
print(res.json())
# Out:
# 200
# {'answer': 'Paris.'}

# %% [markdown]
# #### Case 2: Bad model — `deprecated_model=True`
#
# Passes an invalid model name to OpenRouter, which returns an `APIStatusError` with HTTP status 400 for an unknown model. The endpoint catches it and raises `BadModelError`, which the app-level handler turns into a `404 Not Found` response.

# %%
# Deprecated/bad model name -> 404
question = "hello"
res = test_client.post(
    "/chat",
    params={
        "message": question,
        "deprecated_model": True
    }
)

print(res.status_code)
print(res.json())
# Out:
# 404
# {'error': 'Model Not found', 'message': 'Model name is not valid'}

# %% [markdown]
# #### Case 3: Timeout — `timeout_error=True`
#
# Sets a 0.1-second timeout on a call that would normally take much longer. The `asyncio.TimeoutError` is caught and re-raised as `LLMTimeoutError`, producing a `504 Gateway Timeout`.

# %%
# Timeout -> 504
question = "hello"
res = test_client.post(
    "/chat",
    params={
        "message": question,
        "timeout_error": True
    }
)

print(res.status_code)
print(res.json())
# Out:
# 504
# {'error': 'Request Timed Out', 'message': 'OpenRouter API timed out'}

# %% [markdown]
# #### Case 4: Unsafe content — `unsafe_content=True`
#
# The call itself succeeds (the OpenRouter API responds), but we directly raise `LLMSafetyError()` to simulate what happens when a real safety filter silently blocks the content. No SDK exception is raised here — the handler is triggered purely by the application-level raise.

# %%
# Unsafe content -> 502
question = "hello"
res = test_client.post(
    "/chat",
    params={
        "message": question,
        "unsafe_content": True
    }
)

print(res.status_code)
print(res.json())
# Out:
# 502
# {'error': 'unsafe content', 'message': 'unusable content returned'}

# %% [markdown]
# #### Case 5: Bad key — `bad_key=True`
#
# Creates a client with a deliberately invalid API key. OpenRouter rejects the key with an `APIStatusError` (HTTP 401), which the endpoint catches and re-raises as `LLMAuthError`, producing a `401 Unauthorized`.

# %%
# Bad API key -> 401
question = "hello"
res = test_client.post(
    "/chat",
    params={
        "message": question,
        "bad_key": True
    }
)

print(res.status_code)
print(res.json())
# Out:
# 401
# {'error': 'authorization error', 'message': 'Unable to authenticate with OpenRouter API'}
